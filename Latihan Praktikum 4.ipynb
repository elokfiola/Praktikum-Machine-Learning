# %% [markdown]
# #Latihan Praktikum PM Modul 4
# **Nama**: Elok Fiola
# **NIM**: 122450051
# **Kelas**: RC

# %% [markdown]
# ## Implementasi Klasterisasi K-Means

# %% [markdown]
# ### Iterasi 1

# %%
#Import pustaka atau library yang akna digunakan
import numpy as np
import pandas as pd

# %%
#Masukan dataset yang akan digunakan
#Dtaa titik (X, Y)
data = {
    'A': [1,3],
    'B': [3,3],
    'C': [4,3],
    'D': [5,3],
    'E': [1,2],
    'F': [4,2],
    'G': [1,1],
    'H': [2,1]
}

data = pd.DataFrame(data)
data
# Out:
#    A  B  C  D  E  F  G  H
# 0  1  3  4  5  1  4  1  2
# 1  3  3  3  3  2  2  1  1

# %%
#Inisialisasi centroid awal
centroid_1 = np.array([1,1]) # G(1,1)
centroid_2 = np.array([2,1]) #H(2,1)

# %%
#Fungsi untuk menghitung jarak Euclidea
def euclidean_distance(point, centroid):
  return np.sqrt(np.sum((point - centroid)**2))

#List untuk menyimpan hasil
results = []

# %%
#Menghitung jarak dan menentukan klaster untuk setiap titik
for point, coordinates in data.items():
  coordinates = np.array(coordinates)

  #Menghitung jarak ke masing-masing centroid
  distance_to_centroid_1 = euclidean_distance(coordinates, centroid_1)
  distance_to_centroid_2 = euclidean_distance(coordinates, centroid_2)

  #Menentukan klaster terdekat
  if distance_to_centroid_1 < distance_to_centroid_2:
    nearest_centroid = "C1"
  else:
    nearest_centroid = "C2"

  #Menyimpan hasil
  results.append([point, coordinates[0], coordinates[1], round(distance_to_centroid_1, 2), round(distance_to_centroid_2, 2), nearest_centroid])

# %%
#Membuat dataframe untuk menampilkan tabel
df = pd.DataFrame(results, columns=['Titik', 'X', 'Y', 'Jarak C1', 'Jarak C2', 'Klaster'])

#Menampilan tabel
print(df)
# Out:
#   Titik  X  Y  Jarak C1  Jarak C2 Klaster
# 0     A  1  3      2.00      2.24      C1
# 1     B  3  3      2.83      2.24      C2
# 2     C  4  3      3.61      2.83      C2
# 3     D  5  3      4.47      3.61      C2
# 4     E  1  2      1.00      1.41      C1
# 5     F  4  2      3.16      2.24      C2
# 6     G  1  1      0.00      1.00      C1
# 7     H  2  1      1.00      0.00      C2

# %% [markdown]
# ### Iterasi 2

# %%
#Import pustaka atau library yang akan digunakan
import numpy as np
import pandas as pd

# %%
#Masukan dataset yang akan digunakan
#Dtaa titik (X, Y)
data = {
    'A': [1,3],
    'B': [3,3],
    'C': [4,3],
    'D': [5,3],
    'E': [1,2],
    'F': [4,2],
    'G': [1,1],
    'H': [2,1]
}

data = pd.DataFrame(data)
data
# Out:
#    A  B  C  D  E  F  G  H
# 0  1  3  4  5  1  4  1  2
# 1  3  3  3  3  2  2  1  1

# %%
# Menghitung centroid baru berdasarkan rata-rata titik di klaster C1 dan C2
centroid_1_new = df[df['Klaster'] == 'C1'][['X', 'Y']].mean().values
centroid_2_new = df[df['Klaster'] == 'C2'][['X', 'Y']].mean().values

# Menampilkan centroid baru
print(f"Centroid baru C1: {centroid_1_new}")  # Output: [1.2, 1.2]
print(f"Centroid baru C2: {centroid_2_new}")
# Out:
# Centroid baru C1: [1. 2.]
# Centroid baru C2: [3.6 2.4]

# %%
#Inisialisasi centroid awal
centroid_1 = np.array([1.2, 1.2]) # Centroid 1 baru (1.2, 1.2)
centroid_2 = np.array([3.6, 2.4]) # Centroid 2 baru (3.6, 2.4)

# %%
#Fungsi untuk menghitung jarak Euclidea
def euclidean_distance(point, centroid):
  return np.sqrt(np.sum((point - centroid)**2))

#List untuk menyimpan hasil
results = []

# %%
#Menghitung jarak dan menentukan klaster untuk setiap titik
for index, row in df.iterrows():
  point = row['Titik']
  coordinates = np.array([row['X'], row["Y"]])

  #Menghitung jarak ke masing-masing centroid
  distance_to_centroid_1 = euclidean_distance(coordinates, centroid_1)
  distance_to_centroid_2 = euclidean_distance(coordinates, centroid_2)

  #Menentukan klaster terdekat
  if distance_to_centroid_1 < distance_to_centroid_2:
    nearest_centroid = "C1"
  else:
    nearest_centroid = "C2"

  #Menyimpan hasil
  results.append([point, coordinates[0], coordinates[1], round(distance_to_centroid_1, 2), round(distance_to_centroid_2, 2), nearest_centroid])

# %%
#Membuat dataframe untuk menampilkan tabel
df_results = pd.DataFrame(results, columns=['Titik', 'X', 'Y', 'Jarak C1', 'Jarak C2', 'Klaster'])

#Menampilan tabel
print(df_results)
# Out:
#   Titik  X  Y  Jarak C1  Jarak C2 Klaster
# 0     A  1  3      1.81      2.67      C1
# 1     B  3  3      2.55      0.85      C2
# 2     C  4  3      3.33      0.72      C2
# 3     D  5  3      4.20      1.52      C2
# 4     E  1  2      0.82      2.63      C1
# 5     F  4  2      2.91      0.57      C2
# 6     G  1  1      0.28      2.95      C1
# 7     H  2  1      0.82      2.13      C1

# %%
#Menghitung centroid baru berdasarkan kluster
klaster_1 = df_results[df_results['Klaster'] == 'C1']
klaster_2 = df_results[df_results['Klaster'] == 'C2']

centroid_1_new = np.array([klaster_1['X'].mean(), klaster_1['Y'].mean()])
centroid_2_new = np.array([klaster_2['X'].mean(), klaster_2['Y'].mean()])

print(f"Cetroid baru klaster 1: {centroid_1_new}")
print(f"Cetroid baru klaster 2: {centroid_2_new}")
# Out:
# Cetroid baru klaster 1: [1.25 1.75]
# Cetroid baru klaster 2: [4.   2.75]
